# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def create_barplot(plot_data=None, x_plot=None, y_plot=None, orient='v', plot_title='', order = None, color_bar= "#000000", xlabel_plot='', ylabel_plot='', fig_size=(10,5)):
    fig, ax = plt.subplots(figsize=(fig_size))
    sns.barplot(data=plot_data, y=y_plot, x=x_plot, ax=ax, color=color_bar, order= order, orient=orient)
    ax.set_title(plot_title, fontdict={'fontweight': 'bold', 'fontsize' : 20})
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)
    plt.xlabel(xlabel_plot, fontweight='bold', fontsize=15)
    plt.ylabel(ylabel_plot, fontweight='bold', fontsize=15)
    plt.tight_layout()
    return fig, ax

def create_lineplot(x, y, plot_title, color_line= '#000000', xlabel_plot='', ylabel_plot=''):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.lineplot(x=x, y=y, ax=ax, color=color_line, linewidth=5, marker='o', markersize=15, palette='black')
    ax.set_title(plot_title, fontweight='bold', fontsize=20)
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)
    plt.xlabel(xlabel_plot, fontweight='bold', fontsize=15)
    plt.ylabel(ylabel_plot, fontweight='bold', fontsize=15)
    plt.ylim(0)
    plt.grid(True, linestyle= '--', alpha=0.6)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    return fig, ax

# %%
c1q1 = pd.read_csv('Chapter 1 Question 1.csv')
c1q1
# Out:
#                          job  job_count
# 0               Data Analyst     196579
# 1              Data Engineer     186674
# 2             Data Scientist     172720
# 3           Business Analyst      49160
# 4          Software Engineer      45016
# 5       Senior Data Engineer      44692
# 6      Senior Data Scientist      37076
# 7        Senior Data Analyst      29289
# 8  Machine Learning Engineer      14106
# 9             Cloud Engineer      12346

# %%
create_barplot(plot_data=c1q1, 
               x_plot='job_count', 
															y_plot='job', 
															orient='h', 
															xlabel_plot='Job Posting Count', 
															plot_title= 'Most Demanded Job 2023')
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Most Demanded Job 2023'}, xlabel='Job Posting Count'>)

# %%
c1q2 = pd.read_csv('Chapter 1 Question 2.csv')
c1q2
# Out:
#    month_name  month  job_posting_count
# 0   January        1              92265
# 1   February       2              64558
# 2   March          3              64157
# 3   April          4              62911
# 4   May            5              52232
# 5   June           6              61499
# 6   July           7              63852
# 7   August         8              75063
# 8   September      9              62430
# 9   October       10              66600
# 10  November      11              64401
# 11  December      12              57690

# %%
create_lineplot(x=c1q2.month_name, 
                y=c1q2.job_posting_count, 
																plot_title='Job Vacancy In 2023 by Month', 
																ylabel_plot='Job Posting')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5972\946952993.py:14: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=x, y=y, ax=ax, color=color_line, linewidth=5, marker='o', markersize=15, palette='black')
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Job Vacancy In 2023 by Month'}, ylabel='Job Posting'>)

# %%
c1q3 = pd.read_csv('Chapter 1 Question 3.csv')
c1q3
# Out:
#           country  data_analyst_job
# 0   United States             67948
# 1          France             13855
# 2  United Kingdom             10509
# 3         Germany              7141
# 4       Singapore              6642
# 5           India              6133
# 6           Spain              5182
# 7     Philippines              4770
# 8           Italy              4570
# 9     Netherlands              4126

# %%
create_barplot(plot_data=c1q3, 
               y_plot='country', 
															x_plot='data_analyst_job', 
															orient='h', 
															xlabel_plot='Data Analyst Job Vacancy', 
															plot_title= 'Countries Have The Most Demand for Data Analysts')
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Countries Have The Most Demand for Data Analysts'}, xlabel='Data Analyst Job Vacancy'>)

# %%
c2q1 = pd.read_csv('Chapter 2 Question 1.csv')
c2q1
# Out:
#      skills  job_need_this_skill
# 0       sql                92618
# 1     excel                67021
# 2    python                57326
# 3   tableau                46554
# 4  power bi                39468

# %%
create_barplot(plot_data=c2q1, 
               y_plot='job_need_this_skill', 
															x_plot='skills', 
															orient='v', 
															xlabel_plot='Data Analyst Skill', 
															ylabel_plot='Skill Count in Job Vacancy',
															plot_title= 'Top 5 Most Demanded Skills for Data Anayst')
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Top 5 Most Demanded Skills for Data Anayst'}, xlabel='Data Analyst Skill', ylabel='Skill Count in Job Vacancy'>)

# %%
c2q2 = pd.read_csv('Chapter 2 Question 2.csv')
c2q2
# Out:
#     skills  job_need_this_skill
# 0      sql                17752
# 1   python                11083
# 2  tableau                10015
# 3    excel                 8317
# 4        r                 6252

# %%
create_barplot(plot_data=c2q2, 
               y_plot='job_need_this_skill', 
															x_plot='skills', 
															orient='v', 
															xlabel_plot='Senior Data Analyst Skill', 
															ylabel_plot='Skill Count in Job Vacancy',
															plot_title= 'Top 5 Most Demanded Skills for Senior Data Anayst')
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Top 5 Most Demanded Skills for Senior Data Anayst'}, xlabel='Senior Data Analyst Skill', ylabel='Skill Count in Job Vacancy'>)

# %%
c3q1 = pd.read_csv('Chapter 3 Question 1.csv')
c3q1
# Out:
#       skills  average_salary
# 0     hadoop        85216.96
# 1     looker        85039.08
# 2       jira        85030.44
# 3        aws        84915.11
# 4  snowflake        84850.08
# 5      spark        84821.92
# 6       flow        84405.28
# 7         go        83990.64
# 8    tableau        83921.79
# 9     python        83748.79

# %%
create_barplot(plot_data=c3q1, 
               y_plot='average_salary', 
															x_plot='skills', 
															orient='v', 
															xlabel_plot='Skill', 
															ylabel_plot='Salary',
															plot_title= 'Most Expensive Skills for Data Anayst')
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Most Expensive Skills for Data Anayst'}, xlabel='Skill', ylabel='Salary'>)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(data=c3q1, y='average_salary', x='skills', ax=ax, color='#000000', orient='v')
for p in ax.patches:
            bar_height = p.get_height()
            if not pd.isna(bar_height):
                ax.text(p.get_x() + p.get_width() / 2.,  
                        bar_height,                
                        f'${bar_height:,.0f}',        
                        ha='center',                  
                        va='bottom')  
ax.set_title('Most Expensive Skills for Data Analyst', fontdict={'fontweight': 'bold', 'fontsize': 20})
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)
plt.xlabel('Skill', fontweight='bold', fontsize=15)
plt.ylabel('Average Salary', fontweight='bold', fontsize=15)
plt.tight_layout()

# %%
c3q2 = pd.read_csv('Chapter 3 Question 2.csv')
c3q2
# Out:
#        country  average_salary
# 0   Costa Rica       101751.73
# 1        Chile       100488.98
# 2      Germany       100479.98
# 3        India        98487.21
# 4    Singapore        98477.11
# 5       Mexico        98382.23
# 6      Ireland        93846.07
# 7    Argentina        92748.83
# 8     Colombia        90011.14
# 9  Netherlands        89238.97

# %%
create_barplot(plot_data=c3q2, 
               x_plot='average_salary', 
															y_plot='country', 
															orient='h', 
															xlabel_plot='Average Salary (USD)', 
															ylabel_plot='',
															plot_title= 'How do Salaries for Data Analysts Vary by Country?')
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'How do Salaries for Data Analysts Vary by Country?'}, xlabel='Average Salary (USD)'>)

# %%
c4q1 = pd.read_csv('Chapter 4 Question 1.csv')
c4q1 = c4q1.T.reset_index().rename(columns={'index':'job_type', 0: 'percentage'})
c4q1
# Out:
#             job_type  percentage
# 0  remote_percentage       0.068
# 1  onsite_percentage       0.932

# %%
ax = c4q1.plot(kind='pie', x='job_type', y='percentage', autopct='%1.1f%%', labels=c4q1['job_type'], colormap='copper')
ax.legend().remove()
plt.legend(c4q1.job_type, loc='upper right', bbox_to_anchor=(1, 1))
plt.title('Remote vs Onsite Job Percentage', fontweight='bold', fontsize=16)
plt.tight_layout()
plt.ylabel('')
# Out:
# Text(137.64444444444445, 0.5, '')

# %%
c4q2 = pd.read_csv('Chapter 4 Question 2.csv')
c4q2
# Out:
#   remote_or_onsite  average_salary
# 0           ONSITE        82604.76
# 1           REMOTE        84588.97

# %%
create_barplot(plot_data=c4q2, 
               x_plot='remote_or_onsite', 
															y_plot='average_salary', 
															orient='v', 
															xlabel_plot='', 
															ylabel_plot='Average Salary (USD)',
															plot_title= 'Remote VS On-Site Average Salary',
															fig_size=(5,5))
# Out:
# (<Figure size 500x500 with 1 Axes>,
#  <Axes: title={'center': 'Remote VS On-Site Average Salary'}, ylabel='Average Salary (USD)'>)

# %%
c4q3 = pd.read_csv('Chapter 4 Question 3.csv')
c4q3
# Out:
#      skills  job_need_this_skill
# 0       sql                 7291
# 1     excel                 4611
# 2    python                 4330
# 3   tableau                 3745
# 4  power bi                 2609
# 5         r                 2142
# 6       sas                 1866

# %%
create_barplot(plot_data=c4q3, 
               x_plot='skills', 
															y_plot='job_need_this_skill', 
															orient='v', 
															xlabel_plot='', 
															ylabel_plot='Job Vacancy That Need This Skill',
															plot_title= 'Most in Demand Skills for Remote Job',
															fig_size=(10,5))
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Most in Demand Skills for Remote Job'}, ylabel='Job Vacancy That Need This Skill'>)
